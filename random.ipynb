# %%
# Load and read the log file content
file_path = "challenge1.txt"  # Example path where the text file might be stored

# Read the file to display its content
with open(file_path, "r") as file:
    log_content = file.readlines()


# log_content = log_content[5:]
# # log_content[:5]

# log, website = [], []
# for line in log_content:
#     temp = line.split(' ')
#     website.append(temp[8])

log_content = log_content[5:]

# %%
import numpy as np

# %%
website, msg = [], []
for line in log_content:
    temp = line.split(' ')
    if 'ebikestore' in temp[8]:
        continue
    elif 'weather.cod.edu' in temp[8]:
        continue
    elif 'googleadservices' in temp[8]:
        continue
    elif 'instagram' in temp[8]:
        continue
    elif 'linkedin' in temp[8]:
        continue
    website.append(temp[8])

# %%
website = np.unique(np.array(website))

# %%
for i in (website):
    print(i)
# Out:
# "aax-eu.amazon-adsystem.com/e/dtb/admi?b=JAEvexLtauQAj-4EkXERcR0AAAGTBZrTrgMAAAJYAQBhcHNfdHhuX2JpZDEgICBhcHNfdHhuX2ltcDEgICD9SDUt&rnd=711559414211730965854173&pp=lu0ydc&p=13vak8w&crid=606498057&ep={""ce"":""1""}"
# "ads.yieldmo.com/v000/t_tkr/ev?type=dl&dltime=0&fver=90&imp=563059331820453823&plid=3041482662523904227&pvid=3666726538439378905&fmtid=90&e=11&offsetX=0&offsetY=10039&pvt=1730965865624&stime=1730965866726&etime=1730965866727&viewportHeight=1040&viewportWidth=1919&adSlotLeft=281
# "ads.yieldmo.com/v000/t_tkr/ev?type=fv&imp=563059331820453823&plid=3041482662523904227&pvid=3666726538439378905&fmtid=90&e=11&offsetX=0&offsetY=10039&pvt=1730965865624&stime=1730965866739&etime=1730965866740&viewportHeight=1040&viewportWidth=1919&adSlotLeft=281
# ...

# %%
# len(np.unique(website))
# Out:
# 1989

# %%
'ebikestore' in 'www.ebikestore.com/sales'
# Out:
# True
